# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
import re

pd.set_option('display.max_columns', 300)
plt.style.use('ggplot')

# %%
filepath = './data/news_sample.csv'

df = pd.read_csv(filepath, index_col='id').iloc[:, 1:]
df
# Out:
#                      domain        type  \
# id
# 141                 awm.com  unreliable
# 256       beforeitsnews.com        fake
# 700             cnnnext.com  unreliable
# 768                 awm.com  unreliable
# 791    bipartisanreport.com   clickbait
# ...                     ...         ...
# 39259     beforeitsnews.com        fake
# 39468     beforeitsnews.com        fake
# 39477       www.newsmax.com         NaN
# 39550       www.newsmax.com         NaN
# 39558       www.newsmax.com         NaN
#
#                                                      url  \
# id
# 141    http://awm.com/church-congregation-brings-gift...
# 256    http://beforeitsnews.com/awakening-start-here/...
# 700    http://www.cnnnext.com/video/18526/never-hike-...
# 768    http://awm.com/elusive-alien-of-the-sea-caught...
# 791    http://bipartisanreport.com/2018/01/21/trumps-...
# ...                                                  ...
# 39259  http://beforeitsnews.com/economy/2017/12/priso...
# 39468  http://beforeitsnews.com/diy/2017/11/4-useful-...
# 39477  https://www.newsmax.com/politics/michael-hayde...
# 39550  https://www.newsmax.com/newsfront/antonio-saba...
# 39558  https://www.newsmax.com/newsfront/bill-clinton...
#
#                                                  content  \
# id
# 141    Sometimes the power of Christmas will make you...
# 256    AWAKENING OF 12 STRANDS of DNA – “Reconnecting...
# 700    Never Hike Alone: A Friday the 13th Fan Film U...
# 768    When a rare shark was caught, scientists were ...
# 791    Donald Trump has the unnerving ability to abil...
# ...                                                  ...
# 39259  Prison for Rahm, God’s Work And Many Others\r\...
# 39468  4 Useful Items for Your Tiny Home\r\n\r\nHeadl...
# 39477  Former CIA Director Michael Hayden said Thursd...
# 39550  Antonio Sabato Jr. says Hollywood's liberal el...
# 39558  Former U.S. President Bill Clinton on Monday c...
#
#                        scraped_at                 inserted_at  \
# id
# 141    2018-01-25 16:17:44.789555  2018-02-02 01:19:41.756632
# 256    2018-01-25 16:17:44.789555  2018-02-02 01:19:41.756632
# 700    2018-01-25 16:17:44.789555  2018-02-02 01:19:41.756632
# 768    2018-01-25 16:17:44.789555  2018-02-02 01:19:41.756632
# 791    2018-01-25 16:17:44.789555  2018-02-02 01:19:41.756632
# ...                           ...                         ...
# 39259  2018-01-25 20:13:50.426130  2018-02-02 01:19:41.756632
# 39468  2018-01-25 20:13:50.426130  2018-02-02 01:19:41.756632
# 39477  2018-01-25 20:13:50.426130  2018-02-02 01:19:41.756632
# 39550  2018-01-25 20:13:50.426130  2018-02-02 01:19:41.756632
# 39558  2018-01-25 20:13:50.426130  2018-02-02 01:19:41.756632
#
#                        updated_at  \
# id
# 141    2018-02-02 01:19:41.756664
# 256    2018-02-02 01:19:41.756664
# 700    2018-02-02 01:19:41.756664
# 768    2018-02-02 01:19:41.756664
# 791    2018-02-02 01:19:41.756664
# ...                           ...
# 39259  2018-02-02 01:19:41.756664
# 39468  2018-02-02 01:19:41.756664
# 39477  2018-02-02 01:19:41.756664
# 39550  2018-02-02 01:19:41.756664
# 39558  2018-02-02 01:19:41.756664
#
#                                                    title          authors  \
# id
# 141    Church Congregation Brings Gift to Waitresses ...      Ruth Harris
# 256    AWAKENING OF 12 STRANDS of DNA – “Reconnecting...     Zurich Times
# 700    Never Hike Alone - A Friday the 13th Fan Film ...              NaN
# 768    Elusive ‘Alien Of The Sea ‘ Caught By Scientis...  Alexander Smith
# 791    Trump’s Genius Poll Is Complete & The Results ...  Gloria Christie
# ...                                                  ...              ...
# 39259        Prison for Rahm, God’s Work And Many Others              NaN
# 39468                  4 Useful Items for Your Tiny Home        Dimitry K
# 39477  Michael Hayden: We Should Be 'Frightened' by T...      Todd Beamon
# 39550  Antonio Sabato Jr.: It's Oprah or Bust for Hol...    Bill Hoffmann
# 39558  Bill Clinton Calls for Release of Reuters Jour...              NaN
#
#        keywords                                      meta_keywords  \
# id
# 141         NaN                                               ['']
# 256         NaN                                               ['']
# 700         NaN                                               ['']
# 768         NaN                                               ['']
# 791         NaN                                               ['']
# ...         ...                                                ...
# 39259       NaN                                               ['']
# 39468       NaN                                               ['']
# 39477       NaN  ['michael hayden', 'sthole countries', 'daca',...
# 39550       NaN  ['antonio sabato jr', 'oprah winfrey', 'presid...
# 39558       NaN  ['bill clinton', 'myanmar', 'calls', 'release'...
#
#                                         meta_description  \
# id
# 141                                                  NaN
# 256                                                  NaN
# 700    Never Hike Alone: A Friday the 13th Fan Film  ...
# 768                                                  NaN
# 791                                                  NaN
# ...                                                  ...
# 39259                                                NaN
# 39468                                                NaN
# 39477  President Donald Trump's reported remarks abou...
# 39550  Antonio Sabato Jr. says Hollywood's liberal el...
# 39558  Former U.S. President Bill Clinton Calls for R...
#
#                                                     tags  summary
# id
# 141                                                  NaN      NaN
# 256                                                  NaN      NaN
# 700                                                  NaN      NaN
# 768                                                  NaN      NaN
# 791                                                  NaN      NaN
# ...                                                  ...      ...
# 39259                                                NaN      NaN
# 39468                                                NaN      NaN
# 39477  Homeland Security, Trump Administration, Immig...      NaN
# 39550  Trump Administration, ISIS/Islamic State, News...      NaN
# 39558  Donald Trump, Russia, Trump Administration, Gu...      NaN
#
# [250 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 250 entries, 141 to 39558
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   domain            250 non-null    str
#  1   type              238 non-null    str
#  2   url               250 non-null    str
#  3   content           250 non-null    str
#  4   scraped_at        250 non-null    str
#  5   inserted_at       250 non-null    str
#  6   updated_at        250 non-null    str
#  7   title             250 non-null    str
#  8   authors           170 non-null    str
#  9   keywords          0 non-null      float64
#  10  meta_keywords     250 non-null    str
#  11  meta_description  54 non-null     str
#  12  tags              27 non-null     str
#  13  summary           0 non-null      float64
# dtypes: float64(2), str(12)
# memory usage: 29.3 KB

# %%
df.drop(['keywords','summary'], axis=1, inplace=True)
df = df.fillna('nan')
df['meta_keywords'] = df['meta_keywords'].replace("['']",'nan')

# %%
df.describe().drop(['count','top'], axis=0)
# Out:
#        domain type  url content scraped_at inserted_at updated_at title  \
# unique     29   11  250     239          2           1          1   248
# freq      155  155    1       9        197         250        250     2
#
#        authors meta_keywords meta_description tags
# unique     110            36               52   25
# freq        80           211              196  223
