# %% [markdown]
# <br><h1 style='text-align: center;'>Fake News</h1><br>
# # Part 1 - Data Processing
# ### Task 1 - Small sample

# %%
#!uv add polars numpy matplotlib seaborn nltk

# %%
import polars as pl
import pandas as pd
import matplotlib.pyplot as plt
import re
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

plt.style.use("ggplot")

# %%
_filepath = "./data/news_sample.csv"
df = pl.read_csv(_filepath).drop([""])  # drop the unnamed first column
# Read data
df
# Out:
# shape: (250, 15)
# ┌───────┬────────────┬────────────┬────────────┬───┬────────────┬────────────┬───────────┬─────────┐
# │ id    ┆ domain     ┆ type       ┆ url        ┆ … ┆ meta_keywo ┆ meta_descr ┆ tags      ┆ summary │
# │ ---   ┆ ---        ┆ ---        ┆ ---        ┆   ┆ rds        ┆ iption     ┆ ---       ┆ ---     │
# │ i64   ┆ str        ┆ str        ┆ str        ┆   ┆ ---        ┆ ---        ┆ str       ┆ str     │
# │       ┆            ┆            ┆            ┆   ┆ str        ┆ str        ┆           ┆         │
# ╞═══════╪════════════╪════════════╪════════════╪═══╪════════════╪════════════╪═══════════╪═════════╡
# │ 141   ┆ awm.com    ┆ unreliable ┆ http://awm ┆ … ┆ ['']       ┆ null       ┆ null      ┆ null    │
# │       ┆            ┆            ┆ .com/churc ┆   ┆            ┆            ┆           ┆         │
# │       ┆            ┆            ┆ h-congrega ┆   ┆            ┆            ┆           ┆         │
# │       ┆            ┆            ┆ …          ┆   ┆            ┆            ┆           ┆         │
# │ 256   ┆ beforeitsn ┆ fake       ┆ http://bef ┆ … ┆ ['']       ┆ null       ┆ null      ┆ null    │
# │       ┆ ews.com    ┆            ┆ oreitsnews ┆   ┆            ┆            ┆           ┆         │
# │       ┆            ┆            ┆ .com/awake ┆   ┆            ┆            ┆           ┆         │
# │       ┆            ┆            ┆ …          ┆   ┆            ┆            ┆           ┆         │
# │ 700   ┆ cnnnext.co ┆ unreliable ┆ http://www ┆ … ┆ ['']       ┆ Never Hike ┆ null      ┆ null    │
# │       ┆ m          ┆            ┆ .cnnnext.c ┆   ┆            ┆ Alone: A   ┆           ┆         │
# │       ┆            ┆            ┆ om/video/1 ┆   ┆            ┆ Friday     ┆           ┆         │
# │       ┆            ┆            ┆ …          ┆   ┆            ┆ the…       ┆           ┆         │
# │ 768   ┆ awm.com    ┆ unreliable ┆ http://awm ┆ … ┆ ['']       ┆ null       ┆ null      ┆ null    │
# │       ┆            ┆            ┆ .com/elusi ┆   ┆            ┆            ┆           ┆         │
# │       ┆            ┆            ┆ ve-alien-o ┆   ┆            ┆            ┆           ┆         │
# │       ┆            ┆            ┆ …          ┆   ┆            ┆            ┆           ┆         │
# │ 791   ┆ bipartisan ┆ clickbait  ┆ http://bip ┆ … ┆ ['']       ┆ null       ┆ null      ┆ null    │
# │       ┆ report.com ┆            ┆ artisanrep ┆   ┆            ┆            ┆           ┆         │
# │       ┆            ┆            ┆ ort.com/20 ┆   ┆            ┆            ┆           ┆         │
# │       ┆            ┆            ┆ …          ┆   ┆            ┆            ┆           ┆         │
# │ …     ┆ …          ┆ …          ┆ …          ┆ … ┆ …          ┆ …          ┆ …         ┆ …       │
# │ 39259 ┆ beforeitsn ┆ fake       ┆ http://bef ┆ … ┆ ['']       ┆ null       ┆ null      ┆ null    │
# │       ┆ ews.com    ┆            ┆ oreitsnews ┆   ┆            ┆            ┆           ┆         │
# │       ┆            ┆            ┆ .com/econo ┆   ┆            ┆            ┆           ┆         │
# │       ┆            ┆            ┆ …          ┆   ┆            ┆            ┆           ┆         │
# │ 39468 ┆ beforeitsn ┆ fake       ┆ http://bef ┆ … ┆ ['']       ┆ null       ┆ null      ┆ null    │
# │       ┆ ews.com    ┆            ┆ oreitsnews ┆   ┆            ┆            ┆           ┆         │
# │       ┆            ┆            ┆ .com/diy/2 ┆   ┆            ┆            ┆           ┆         │
# │       ┆            ┆            ┆ …          ┆   ┆            ┆            ┆           ┆         │
# │ 39477 ┆ www.newsma ┆ null       ┆ https://ww ┆ … ┆ ['michael  ┆ President  ┆ Homeland  ┆ null    │
# │       ┆ x.com      ┆            ┆ w.newsmax. ┆   ┆ hayden',   ┆ Donald     ┆ Security, ┆         │
# │       ┆            ┆            ┆ com/politi ┆   ┆ 'sthole    ┆ Trump's    ┆ Trump     ┆         │
# │       ┆            ┆            ┆ …          ┆   ┆ cou…       ┆ repor…     ┆ Admin…    ┆         │
# │ 39550 ┆ www.newsma ┆ null       ┆ https://ww ┆ … ┆ ['antonio  ┆ Antonio    ┆ Trump Adm ┆ null    │
# │       ┆ x.com      ┆            ┆ w.newsmax. ┆   ┆ sabato     ┆ Sabato Jr. ┆ inistrati ┆         │
# │       ┆            ┆            ┆ com/newsfr ┆   ┆ jr',       ┆ says       ┆ on,       ┆         │
# │       ┆            ┆            ┆ …          ┆   ┆ 'oprah w…  ┆ Hollyw…    ┆ ISIS/Isl… ┆         │
# │ 39558 ┆ www.newsma ┆ null       ┆ https://ww ┆ … ┆ ['bill     ┆ Former     ┆ Donald    ┆ null    │
# │       ┆ x.com      ┆            ┆ w.newsmax. ┆   ┆ clinton',  ┆ U.S.       ┆ Trump,    ┆         │
# │       ┆            ┆            ┆ com/newsfr ┆   ┆ 'myanmar', ┆ President  ┆ Russia,   ┆         │
# │       ┆            ┆            ┆ …          ┆   ┆ 'c…        ┆ Bill Cli…  ┆ Trump Ad… ┆         │
# └───────┴────────────┴────────────┴────────────┴───┴────────────┴────────────┴───────────┴─────────┘

# %%
print(df.schema)
print(f"Shape: {df.shape}")
print(f"Null counts:\n{df.null_count()}")
# Out:
# Schema({'id': Int64, 'domain': String, 'type': String, 'url': String, 'content': String, 'scraped_at': String, 'inserted_at': String, 'updated_at': String, 'title': String, 'authors': String, 'keywords': String, 'meta_keywords': String, 'meta_description': String, 'tags': String, 'summary': String})
# Shape: (250, 15)
# Null counts:
# shape: (1, 15)
# ┌─────┬────────┬──────┬─────┬───┬───────────────┬──────────────────┬──────┬─────────┐
# │ id  ┆ domain ┆ type ┆ url ┆ … ┆ meta_keywords ┆ meta_description ┆ tags ┆ summary │
# │ --- ┆ ---    ┆ ---  ┆ --- ┆   ┆ ---           ┆ ---              ┆ ---  ┆ ---     │
# │ u32 ┆ u32    ┆ u32  ┆ u32 ┆   ┆ u32           ┆ u32              ┆ u32  ┆ u32     │
# ╞═════╪════════╪══════╪═════╪═══╪═══════════════╪══════════════════╪══════╪═════════╡
# │ 0   ┆ 0      ┆ 12   ┆ 0   ┆ … ┆ 0             ┆ 196              ┆ 223  ┆ 250     │
# └─────┴────────┴──────┴─────┴───┴───────────────┴──────────────────┴──────┴─────────┘

# %%
df_1 = (
    df.drop(["keywords", "summary"])
    .fill_null("nan")
    .with_columns(
        pl.when(pl.col("meta_keywords") == "['']")
        .then(pl.lit("nan"))
        .otherwise(pl.col("meta_keywords"))
        .alias("meta_keywords")
    )
)
df_1
# Out:
# shape: (250, 13)
# ┌───────┬────────────┬────────────┬────────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ id    ┆ domain     ┆ type       ┆ url        ┆ … ┆ authors   ┆ meta_keyw ┆ meta_desc ┆ tags      │
# │ ---   ┆ ---        ┆ ---        ┆ ---        ┆   ┆ ---       ┆ ords      ┆ ription   ┆ ---       │
# │ i64   ┆ str        ┆ str        ┆ str        ┆   ┆ str       ┆ ---       ┆ ---       ┆ str       │
# │       ┆            ┆            ┆            ┆   ┆           ┆ str       ┆ str       ┆           │
# ╞═══════╪════════════╪════════════╪════════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 141   ┆ awm.com    ┆ unreliable ┆ http://awm ┆ … ┆ Ruth      ┆ nan       ┆ nan       ┆ nan       │
# │       ┆            ┆            ┆ .com/churc ┆   ┆ Harris    ┆           ┆           ┆           │
# │       ┆            ┆            ┆ h-congrega ┆   ┆           ┆           ┆           ┆           │
# │       ┆            ┆            ┆ …          ┆   ┆           ┆           ┆           ┆           │
# │ 256   ┆ beforeitsn ┆ fake       ┆ http://bef ┆ … ┆ Zurich    ┆ nan       ┆ nan       ┆ nan       │
# │       ┆ ews.com    ┆            ┆ oreitsnews ┆   ┆ Times     ┆           ┆           ┆           │
# │       ┆            ┆            ┆ .com/awake ┆   ┆           ┆           ┆           ┆           │
# │       ┆            ┆            ┆ …          ┆   ┆           ┆           ┆           ┆           │
# │ 700   ┆ cnnnext.co ┆ unreliable ┆ http://www ┆ … ┆ nan       ┆ nan       ┆ Never     ┆ nan       │
# │       ┆ m          ┆            ┆ .cnnnext.c ┆   ┆           ┆           ┆ Hike      ┆           │
# │       ┆            ┆            ┆ om/video/1 ┆   ┆           ┆           ┆ Alone: A  ┆           │
# │       ┆            ┆            ┆ …          ┆   ┆           ┆           ┆ Friday    ┆           │
# │       ┆            ┆            ┆            ┆   ┆           ┆           ┆ the…      ┆           │
# │ 768   ┆ awm.com    ┆ unreliable ┆ http://awm ┆ … ┆ Alexander ┆ nan       ┆ nan       ┆ nan       │
# │       ┆            ┆            ┆ .com/elusi ┆   ┆ Smith     ┆           ┆           ┆           │
# │       ┆            ┆            ┆ ve-alien-o ┆   ┆           ┆           ┆           ┆           │
# │       ┆            ┆            ┆ …          ┆   ┆           ┆           ┆           ┆           │
# │ 791   ┆ bipartisan ┆ clickbait  ┆ http://bip ┆ … ┆ Gloria    ┆ nan       ┆ nan       ┆ nan       │
# │       ┆ report.com ┆            ┆ artisanrep ┆   ┆ Christie  ┆           ┆           ┆           │
# │       ┆            ┆            ┆ ort.com/20 ┆   ┆           ┆           ┆           ┆           │
# │       ┆            ┆            ┆ …          ┆   ┆           ┆           ┆           ┆           │
# │ …     ┆ …          ┆ …          ┆ …          ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 39259 ┆ beforeitsn ┆ fake       ┆ http://bef ┆ … ┆ nan       ┆ nan       ┆ nan       ┆ nan       │
# │       ┆ ews.com    ┆            ┆ oreitsnews ┆   ┆           ┆           ┆           ┆           │
# │       ┆            ┆            ┆ .com/econo ┆   ┆           ┆           ┆           ┆           │
# │       ┆            ┆            ┆ …          ┆   ┆           ┆           ┆           ┆           │
# │ 39468 ┆ beforeitsn ┆ fake       ┆ http://bef ┆ … ┆ Dimitry K ┆ nan       ┆ nan       ┆ nan       │
# │       ┆ ews.com    ┆            ┆ oreitsnews ┆   ┆           ┆           ┆           ┆           │
# │       ┆            ┆            ┆ .com/diy/2 ┆   ┆           ┆           ┆           ┆           │
# │       ┆            ┆            ┆ …          ┆   ┆           ┆           ┆           ┆           │
# │ 39477 ┆ www.newsma ┆ nan        ┆ https://ww ┆ … ┆ Todd      ┆ ['michael ┆ President ┆ Homeland  │
# │       ┆ x.com      ┆            ┆ w.newsmax. ┆   ┆ Beamon    ┆ hayden',  ┆ Donald    ┆ Security, │
# │       ┆            ┆            ┆ com/politi ┆   ┆           ┆ 'sthole   ┆ Trump's   ┆ Trump     │
# │       ┆            ┆            ┆ …          ┆   ┆           ┆ cou…      ┆ repor…    ┆ Admin…    │
# │ 39550 ┆ www.newsma ┆ nan        ┆ https://ww ┆ … ┆ Bill      ┆ ['antonio ┆ Antonio   ┆ Trump Adm │
# │       ┆ x.com      ┆            ┆ w.newsmax. ┆   ┆ Hoffmann  ┆ sabato    ┆ Sabato    ┆ inistrati │
# │       ┆            ┆            ┆ com/newsfr ┆   ┆           ┆ jr',      ┆ Jr. says  ┆ on,       │
# │       ┆            ┆            ┆ …          ┆   ┆           ┆ 'oprah w… ┆ Hollyw…   ┆ ISIS/Isl… │
# │ 39558 ┆ www.newsma ┆ nan        ┆ https://ww ┆ … ┆ nan       ┆ ['bill    ┆ Former    ┆ Donald    │
# │       ┆ x.com      ┆            ┆ w.newsmax. ┆   ┆           ┆ clinton', ┆ U.S.      ┆ Trump,    │
# │       ┆            ┆            ┆ com/newsfr ┆   ┆           ┆ 'myanmar' ┆ President ┆ Russia,   │
# │       ┆            ┆            ┆ …          ┆   ┆           ┆ , 'c…     ┆ Bill Cli… ┆ Trump Ad… │
# └───────┴────────────┴────────────┴────────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
df_1.describe()
# Out:
# shape: (9, 14)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ statistic ┆ id        ┆ domain    ┆ type      ┆ … ┆ authors   ┆ meta_keyw ┆ meta_desc ┆ tags     │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ords      ┆ ription   ┆ ---      │
# │ str       ┆ f64       ┆ str       ┆ str       ┆   ┆ str       ┆ ---       ┆ ---       ┆ str      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ str       ┆ str       ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ count     ┆ 250.0     ┆ 250       ┆ 250       ┆ … ┆ 250       ┆ 250       ┆ 250       ┆ 250      │
# │ null_coun ┆ 0.0       ┆ 0         ┆ 0         ┆ … ┆ 0         ┆ 0         ┆ 0         ┆ 0        │
# │ t         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ mean      ┆ 20241.56  ┆ null      ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ std       ┆ 11515.412 ┆ null      ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │           ┆ 728       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ min       ┆ 141.0     ┆ 21stcentu ┆ bias      ┆ … ┆ A Bad     ┆ ['', 'Big ┆ 'Enough   ┆ Achievem │
# │           ┆           ┆ rywire.co ┆           ┆   ┆ Witch'S   ┆ Governmen ┆ meddling  ┆ ent Gap, │
# │           ┆           ┆ m         ┆           ┆   ┆ Blog      ┆ t', 'mark ┆ ... Go    ┆ GOP      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ l…        ┆ home, …   ┆ Share Of │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ …        │
# │ 25%       ┆ 11001.0   ┆ null      ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 50%       ┆ 21093.0   ┆ null      ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 75%       ┆ 29104.0   ┆ null      ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ max       ┆ 39558.0   ┆ www.newsm ┆ unreliabl ┆ … ┆ nan       ┆ nan       ┆ “We are   ┆ out of   │
# │           ┆           ┆ ax.com    ┆ e         ┆   ┆           ┆           ┆ on the    ┆ iraq,    │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ precipice ┆ end the  │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ of co…    ┆ occupati │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ o…       │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
# Helper function to collect tokens labeled as <OTHER>
def _collect_other(token, log):
    if log is not None:
        log.append(token)
    return "<OTHER>"


# Pattern strings — shared with Task 2 (Polars uses these directly)
email_re = re.compile(r'[^ \n,"]+@[^ \n,"]+\.[^ \n,"]+')
date_re = re.compile(r'[0-9]{2,4}[-/][0-9]{2,4}[-/][0-9]{2,4}')
url_re = re.compile(r'(?:http)?s?(?://)?[^ \n,"]+\.[a-z]{2,}[^ \n,"]+')
num_re = re.compile(r'[0-9]+[,.]?[0-9]*')
special_re = re.compile(r"""[.,/—–!\\"#$%&'()*+:;=?@\[\\\]^_`{|}~€£¥§±×÷°•¶©®™¢∞≠≈≤≥√∑πµω∆∫]""")
ws_re = re.compile(r'\s+')

def clean_text(doc: str):
    lower_case = doc.lower()
    substituted = email_re.sub(" <EMAIL> ", lower_case)
    substituted = date_re.sub(" <DATE> ", substituted)
    substituted = url_re.sub(" <URL> ", substituted)
    substituted = num_re.sub(" <NUM> ", substituted)
    no_specials = special_re.sub(" ", substituted)
    cleaned = ws_re.sub(' ', no_specials).strip()
    return cleaned

# %% [markdown]
# <br><br><br>
# <h1 style='text-align : center;'>CHECK OTHER</h1>
# <br><br><br>

# %%
# # Check for most common tokens replaced by <OTHER>
# other_tokens = []
# for doc in df["content"].dropna().head(500):
#     clean_text(doc, other_log=other_tokens)

# # Show most common tokens replaced by <OTHER>
# other_counts = pd.Series(other_tokens).value_counts()[:20]

# print(f"Unique tokens mapped to <OTHER>: {len(other_counts)}")
# other_counts

# %%
natural_language_cols = [
    "content",
    "title",
    "authors",
    "meta_keywords",
    "meta_description",
]


def clean(df: pl.DataFrame, nlc: list[str] = natural_language_cols):
    # Given a DataFrame and potentially
    #   1. a list, nlc, of natural language columns (default: "natural_language_cols")
    # Returns new DataFrame with nlc cleaned.
    return df.with_columns(
        [
            pl.col(col)
            .map_elements(lambda x: clean_text(x), return_dtype=pl.String)
            .alias(col)
            for col in nlc
        ]
    )


# df = clean(df)
df_1.filter(pl.col("meta_keywords") != "nan").select(
    natural_language_cols
).head()
# Out:
# shape: (5, 5)
# ┌───────────────────┬───────────────────┬───────────────────┬───────────────────┬──────────────────┐
# │ content           ┆ title             ┆ authors           ┆ meta_keywords     ┆ meta_description │
# │ ---               ┆ ---               ┆ ---               ┆ ---               ┆ ---              │
# │ str               ┆ str               ┆ str               ┆ str               ┆ str              │
# ╞═══════════════════╪═══════════════════╪═══════════════════╪═══════════════════╪══════════════════╡
# │ President Trump,  ┆ In Calling Out    ┆ Hamilton          ┆ ['fake news',     ┆ Stephen E.       │
# │ right, with R…    ┆ 'Fake News,' Do…  ┆ Strategies        ┆ 'donald trump', … ┆ Strang, author   │
# │                   ┆                   ┆                   ┆                   ┆ of '…            │
# │ Subscribe to      ┆ Obama and         ┆ Joseph Harris,    ┆ ['Conservative    ┆ News, Politics,  │
# │ Canada Free       ┆ Redistribution of ┆ Because Without…  ┆ News', 'Conserv…  ┆ Editorials, co…  │
# │ Press…            ┆ Yo…               ┆                   ┆                   ┆                  │
# │ President Trump’s ┆ Ben Cardin:       ┆ Joel Gehrke       ┆ ['Rex Tillerson', ┆ “We are on the   │
# │ plan to cont…     ┆ Trump's new Syria ┆                   ┆ 'ISIS', 'Sen…     ┆ precipice of co… │
# │                   ┆ …                 ┆                   ┆                   ┆                  │
# │ Something is      ┆ Newsweek 'fact    ┆ Becket Adams      ┆ ['Fake News',     ┆ What's the use   │
# │ wrong at          ┆ check' denies R…  ┆                   ┆ 'Clinton Foundat… ┆ of fact checkin… │
# │ Newsweek…         ┆                   ┆                   ┆                   ┆                  │
# │ American forces   ┆ Byron York: U.S.  ┆ Byron York        ┆ ['ISIS',          ┆ Of a group of    │
# │ made one of th…   ┆ ran out of am…    ┆                   ┆ 'National         ┆ 300 oil tankers  │
# │                   ┆                   ┆                   ┆ Security', …      ┆ …                │
# └───────────────────┴───────────────────┴───────────────────┴───────────────────┴──────────────────┘

# %%
def rm_stop_words(df: pl.DataFrame, nlc: list[str] = natural_language_cols):
    #Removes stop words from DataFrame with i/o as for the clean function.
    _stop_words = set(stopwords.words("english"))
    return df.with_columns(
        [
            pl.col(col)
            .map_elements(
                lambda x: " ".join(
                    [w for w in x.split() if w not in _stop_words]
                ),
                return_dtype=pl.String,
            )
            .alias(col)
            for col in nlc
        ]
    )

def stem(df: pl.DataFrame, nlc: list[str] = natural_language_cols):
    #Stems DataFrame with i/o as for the clean function.
    _stemmer = PorterStemmer()
    return df.with_columns(
        [
            pl.col(col)
            .map_elements(
                lambda x: " ".join([_stemmer.stem(w) for w in x.split()]),
                return_dtype=pl.String,
            )
            .alias(col)
            for col in nlc
        ]
    )

def preprocess(
    df: pl.DataFrame, nlc: list[str] = natural_language_cols, progbar=False
):
    # General preprocessing function — faster than combining clean, rm_stop_words, stem.
    _stop_words = set(stopwords.words("english"))
    _stemmer = PorterStemmer()
    return df.with_columns(
        [
            pl.col(col)
            .map_elements(
                lambda x: " ".join(
                    [
                        _stemmer.stem(w)
                        for w in clean_text(x).split()
                        if w not in _stop_words
                    ]
                ),
                return_dtype=pl.String,
            )
            .alias(col)
            for col in nlc
        ]
    )

df_clean = preprocess(df_1)
df_clean.select(natural_language_cols)
# Out:
# shape: (250, 5)
# ┌────────────────────┬────────────────────┬────────────────┬───────────────────┬───────────────────┐
# │ content            ┆ title              ┆ authors        ┆ meta_keywords     ┆ meta_description  │
# │ ---                ┆ ---                ┆ ---            ┆ ---               ┆ ---               │
# │ str                ┆ str                ┆ str            ┆ str               ┆ str               │
# ╞════════════════════╪════════════════════╪════════════════╪═══════════════════╪═══════════════════╡
# │ sometim power      ┆ church congreg     ┆ ruth harri     ┆ nan               ┆ nan               │
# │ christma make wi…  ┆ bring gift wait…   ┆                ┆                   ┆                   │
# │ awaken <num>       ┆ awaken <num>       ┆ zurich time    ┆ nan               ┆ nan               │
# │ strand dna “recon… ┆ strand dna “recon… ┆                ┆                   ┆                   │
# │ never hike alon    ┆ never hike alon -  ┆ nan            ┆ nan               ┆ never hike alon   │
# │ friday <num> t…    ┆ friday <num>…      ┆                ┆                   ┆ friday <num> t…   │
# │ rare shark caught  ┆ elus ‘alien sea ‘  ┆ alexand smith  ┆ nan               ┆ nan               │
# │ scientist le…      ┆ caught scien…      ┆                ┆                   ┆                   │
# │ donald trump       ┆ trump’ geniu poll  ┆ gloria christi ┆ nan               ┆ nan               │
# │ unnerv abil abil … ┆ complet resu…      ┆                ┆                   ┆                   │
# │ …                  ┆ …                  ┆ …              ┆ …                 ┆ …                 │
# │ prison rahm god’   ┆ prison rahm god’   ┆ nan            ┆ nan               ┆ nan               │
# │ work mani oth…     ┆ work mani oth…     ┆                ┆                   ┆                   │
# │ <num> use item     ┆ <num> use item     ┆ dimitri k      ┆ nan               ┆ nan               │
# │ tini home headl…   ┆ tini home          ┆                ┆                   ┆                   │
# │ former cia         ┆ michael hayden     ┆ todd beamon    ┆ michael hayden    ┆ presid donald     │
# │ director michael   ┆ frighten trump …   ┆                ┆ sthole countri …  ┆ trump report rem… │
# │ ha…                ┆                    ┆                ┆                   ┆                   │
# │ antonio sabato jr  ┆ antonio sabato jr  ┆ bill hoffmann  ┆ antonio sabato jr ┆ antonio sabato jr │
# │ say hollywoo…      ┆ oprah bust h…      ┆                ┆ oprah winfre…     ┆ say hollywoo…     │
# │ former u presid    ┆ bill clinton call  ┆ nan            ┆ bill clinton      ┆ former u presid   │
# │ bill clinton m…    ┆ releas reute…      ┆                ┆ myanmar call      ┆ bill clinton c…   │
# │                    ┆                    ┆                ┆ rele…             ┆                   │
# └────────────────────┴────────────────────┴────────────────┴───────────────────┴───────────────────┘

# %%
# Make Zipf's law plot of the 50 most common tokens after preprocessing
# Gather all text from NL columns, split into tokens, count
all_text = " ".join(
    df_clean.select(natural_language_cols)
    .fill_null("")
    .unpivot()
    .get_column("value")
    .to_list()
)
from collections import Counter

token_counts = Counter(all_text.split())
most_common = token_counts.most_common(50)
words, counts = zip(*most_common)

plt.figure(figsize=(24, 8))
plt.plot(list(words), list(counts))
plt.xticks(rotation=35, ha="right")
plt.show()

# %% [markdown]
# ### Task 2 - Bigger subset

# %%
# import os
# import Stemmer  # PyStemmer (~10× faster than NLTK)

# #_filepath = "news/data/995,000_rows.csv"
# _outpath = "news/data/995,000_rows_preprocessed.csv"
# _chunk_size = 50_000

# # Preprocess resources (initialized once)
# _stop_words = set(stopwords.words("english"))
# _stemmer = Stemmer.Stemmer("english")

# def _stem_and_filter(x: str) -> str:
#     words = [w for w in x.split() if w not in _stop_words]
#     return " ".join(_stemmer.stemWords(words))

# # Remove old output file if it exists so we can append fresh
# if os.path.exists(_outpath):
#     os.remove(_outpath)

# # Use scan_csv (lazy) and process in chunks to keep memory low
# _lf = pl.scan_csv(_filepath)
# _total_rows = _lf.select(pl.len()).collect().item()
# _n_chunks = (_total_rows + _chunk_size - 1) // _chunk_size
# print(
#     f"Processing {_total_rows} rows in {_n_chunks} chunks of {_chunk_size}..."
# )

# for _i in range(_n_chunks):
#     _offset = _i * _chunk_size
#     # Collect only this chunk from the lazy frame
#     _chunk = (
#         _lf.slice(_offset, _chunk_size)
#         .drop(["id", "Unnamed: 0", "keywords", "summary"])
#         .collect()
#     )
#     # Fill nulls
#     _chunk = _chunk.fill_null("nan")
#     _chunk = _chunk.with_columns(
#         pl.when(pl.col("meta_keywords") == "['']")
#         .then(pl.lit("nan"))
#         .otherwise(pl.col("meta_keywords"))
#         .alias("meta_keywords")
#     )
#     # --- Regex cleaning via native Polars (runs in Rust, not Python) ---
#     _chunk = _chunk.with_columns(
#         [
#             pl.col(col)
#             .str.to_lowercase()
#             .str.replace_all(email_pat, " <EMAIL> ")
#             .str.replace_all(date_pat, " <DATE> ")
#             .str.replace_all(url_pat, " <URL> ")
#             .str.replace_all(num_pat, " <NUM> ")
#             .str.replace_all(special_pat, " ")
#             .str.replace_all(ws_pat, " ")
#             .str.strip_chars()
#             for col in natural_language_cols
#         ]
#     )
#     # --- Stop-word removal + stemming (PyStemmer is C-based, ~10× faster) ---
#     _chunk = _chunk.with_columns(
#         [
#             pl.col(col)
#             .map_elements(_stem_and_filter, return_dtype=pl.String)
#             .alias(col)
#             for col in natural_language_cols
#         ]
#     )
#     # Write: first chunk with header (creates file), rest append without header
#     if _i == 0:
#         _chunk.write_csv(_outpath)
#     else:
#         with open(_outpath, "a") as _f:
#             _chunk.write_csv(_f, include_header=False)
#     print(
#         f"  Chunk {_i + 1}/{_n_chunks} done ({_offset + len(_chunk)} rows so far)"
#     )
#     del _chunk  # Free memory immediately

# print("Done. Preprocessed data saved to", _outpath)

# %%
df = pl.read_csv("./data/995,000_rows_preprocessed.csv").to_pandas()
df
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniconda/base/envs/gds/lib/python3.13/site-packages/polars/io/csv/functions.py:560, in read_csv(source, has_header, columns, new_columns, separator, comment_prefix, quote_char, skip_rows, skip_lines, schema, schema_overrides, null_values, missing_utf8_is_empty_string, ignore_errors, try_parse_dates, n_threads, infer_schema, infer_schema_length, batch_size, n_rows, encoding, low_memory, rechunk, use_pyarrow, storage_options, skip_rows_after_header, row_index_name, row_index_offset, sample_size, eol_char, raise_if_empty, truncate_ragged_lines, decimal_comma, glob)
#     553     with prepare_file_arg(
#     554         source,
#     555         encoding=encoding,
#    (...)    558         storage_options=storage_options,
#     559     ) as data:
# --> 560         df = _read_csv_impl(
#     561             data,
#     562             has_header=has_header,
#     563             columns=columns if columns else projection,
#     564             separator=separator,
#     565             comment_prefix=comment_prefix,
#     566             quote_char=quote_char,
#     567             skip_rows=skip_rows,
#     568             skip_lines=skip_lines,
#     569             schema_overrides=schema_overrides,
#     570             schema=schema,
#     571             null_values=null_values,
#     572             missing_utf8_is_empty_string=missing_utf8_is_empty_string,
#     573             ignore_errors=ignore_errors,
#     574             try_parse_dates=try_parse_dates,
#     575             n_threads=n_threads,
#     576             infer_schema_length=infer_schema_length,
#     577             batch_size=batch_size,
#     578             n_rows=n_rows,
#     579             encoding=encoding if encoding == "utf8-lossy" else "utf8",
#     580             low_memory=low_memory,
#     581             rechunk=rechunk,
#     582             skip_rows_after_header=skip_rows_after_header,
#     583             row_index_name=row_index_name,
#     584             row_index_offset=row_index_offset,
#     585             eol_char=eol_char,
#     586             raise_if_empty=raise_if_empty,
#     587             truncate_ragged_lines=truncate_ragged_lines,
#     588             decimal_comma=decimal_comma,
#     589             glob=glob,
#     590         )
#     592 if new_columns:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/gds/lib/python3.13/site-packages/polars/io/csv/functions.py:708, in _read_csv_impl(source, has_header, columns, separator, comment_prefix, quote_char, skip_rows, skip_lines, schema, schema_overrides, null_values, missing_utf8_is_empty_string, ignore_errors, try_parse_dates, n_threads, infer_schema_length, batch_size, n_rows, encoding, low_memory, rechunk, skip_rows_after_header, row_index_name, row_index_offset, sample_size, eol_char, raise_if_empty, truncate_ragged_lines, decimal_comma, glob)
#     706 projection, columns = parse_columns_arg(columns)
# --> 708 pydf = PyDataFrame.read_csv(
#     709     source,
#     710     infer_schema_length,
#     711     batch_size,
#     712     has_header,
#     713     ignore_errors,
#     714     n_rows,
#     715     skip_rows,
#     716     skip_lines,
#     717     projection,
#     718     separator,
#     719     rechunk,
#     720     columns,
#     721     encoding,
#     722     n_threads,
#     723     path,
#     724     dtype_list,
#     725     dtype_slice,
#     726     low_memory,
#     727     comment_prefix,
#     728     quote_char,
#     729     processed_null_values,
#     730     missing_utf8_is_empty_string,
#     731     try_parse_dates,
#     732     skip_rows_after_header,
#     733     parse_row_index_args(row_index_name, row_index_offset),
#     734     eol_char=eol_char,
#     735     raise_if_empty=raise_if_empty,
#     736     truncate_ragged_lines=truncate_ragged_lines,
#     737     decimal_comma=decimal_comma,
#     738     schema=schema,
#     739 )
#     740 return wrap_df(pydf)
#
# OSError: Interrupted system call (os error 4)
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df = pl.read_csv("./data/995,000_rows_preprocessed.csv").to_pandas()
#       2 df
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/gds/lib/python3.13/site-packages/polars/_utils/deprecation.py:128, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     123 @wraps(function)
#     124 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     125     _rename_keyword_argument(
#     126         old_name, new_name, kwargs, function.__qualname__, version
#     127     )
# --> 128     return function(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/gds/lib/python3.13/site-packages/polars/_utils/deprecation.py:128, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     123 @wraps(function)
#     124 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     125     _rename_keyword_argument(
#     126         old_name, new_name, kwargs, function.__qualname__, version
#     127     )
# --> 128     return function(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/gds/lib/python3.13/site-packages/polars/_utils/deprecation.py:128, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     123 @wraps(function)
#     124 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     125     _rename_keyword_argument(
#     126         old_name, new_name, kwargs, function.__qualname__, version
#     127     )
# --> 128     return function(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/gds/lib/python3.13/site-packages/polars/io/csv/functions.py:553, in read_csv(source, has_header, columns, new_columns, separator, comment_prefix, quote_char, skip_rows, skip_lines, schema, schema_overrides, null_values, missing_utf8_is_empty_string, ignore_errors, try_parse_dates, n_threads, infer_schema, infer_schema_length, batch_size, n_rows, encoding, low_memory, rechunk, use_pyarrow, storage_options, skip_rows_after_header, row_index_name, row_index_offset, sample_size, eol_char, raise_if_empty, truncate_ragged_lines, decimal_comma, glob)
#     550     df = lf.collect()
#     552 else:
# --> 553     with prepare_file_arg(
#     554         source,
#     555         encoding=encoding,
#     556         use_pyarrow=False,
#     557         raise_if_empty=raise_if_empty,
#     558         storage_options=storage_options,
#     559     ) as data:
#     560         df = _read_csv_impl(
#     561             data,
#     562             has_header=has_header,
#    (...)    589             glob=glob,
#     590         )
#     592 if new_columns:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/gds/lib/python3.13/contextlib.py:145, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     142     except StopIteration:
#     143         raise RuntimeError("generator didn't yield") from None
# --> 145 def __exit__(self, typ, value, traceback):
#     146     if typ is None:
#     147         try:
#
# KeyboardInterrupt:

# %%
# 1. counting the number of URLs in the content
import sys

vocab = {}
for idx,col in enumerate(natural_language_cols):
    sys.stdout.write(f'\rCols: {idx+1}/{len(natural_language_cols)}')
    for cell in df[col]:
        for w in cell.split():
            if w in vocab:
                vocab[w] += 1
            else:
                vocab[w] = 1

# %%
top_vocab = vocab.head(100)
plt.figure(figsize=(32,12))
plt.plot(top_vocab['count'])
plt.xticks(top_vocab.index)
plt.xticks(rotation=35, ha='right')
plt.show()

# %%
vocab.reset_index().query('token == "trump"')

# %%
<br><h1 style='text-align: center;'>Task 3</h1><br>
# Out:
#   Cell In[1], line 1
#     <br><h1 style='text-align: center;'>Task 3</h1><br>
#     ^
# SyntaxError: invalid syntax

# %%
special_tokens = ['<URL>','<EMAIL>','<DATE>','<NUM>']

for special in special_tokens:
    print(vocab.reset_index().query(f'token == "{special}"'))
    print()
    print()
